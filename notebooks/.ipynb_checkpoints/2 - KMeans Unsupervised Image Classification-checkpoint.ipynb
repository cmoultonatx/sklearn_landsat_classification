# %% [markdown]
# # KMeans Unsupervised Image Classification
#
# This script implements a KMeans classifier to classify landcover for our newly created composite Landsat image.
# The workflow follows a typical scikit-learn machine learning workflow without the need for training data,
# KMeans can easily be replaced with other unsupervised classifiers in the scikit-learn toolkit. We first read in
# the input GeoTIFF as an n-dimensional numpy array, corresponding to how many bands we chose to stack in the
# first script. We then reshape the dataset to 2-D, instantiate a KMeans classifier object, and lastly fit and predict classifications on those same values. In essence, we are using the scikit-learn classifier to auto-detect clusters
# of like band combinations, which correspond to the reflectance of each pixel's footprint on the real world.
#
# The inputs to this script are:
# * Input GeoTIFF path, the outputs of the previous scripts
# * Number of classes to look for, the higher the number the longer the processing time
# * Output GeoTIFF path for the predicted classes to be saved to

# %%
from osgeo import gdal, osr
from sklearn.cluster import KMeans
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Again, change the in_tif variable to the output path of the previous scripts. This can be either the
# clipped or the entire image.

# %%
in_tif = r"..\..\data\Austin_Landsat_Clip.tif"
number_of_classes = 5
out_tif = r"..\..\data\Austin_KMeans_Class.tif"

in_ds = gdal.Open(in_tif)
arr_list = []

#Adds each band as an array
#I'm sure there's a more efficient way to get a GDAL raster as an n-dimensional array tho...
for i in range(1, in_ds.RasterCount +1):
    band = in_ds.GetRasterBand(i)
    arr = band.ReadAsArray()
    arr_list.append(arr)
in_data = np.dstack(np.array(arr_list)).T

# %% [markdown]
# This cell reshapes the n-dimensional array to 2-dimensions

# %%
samples = in_data.reshape((in_data.shape[0],-1)).T
y = np.ones(samples.shape)

# %% [markdown]
# This cell sets up the KMeans classifier with n_clusters, eg spectral signature classifications.
# This will take a little while to run...

# %%
kmeans = KMeans(n_clusters=number_of_classes).fit_predict(samples)

# %% [markdown]
# This cell creates a new labels array from the output predictions and then
# reshapes to the original dimensions of the dataset

# %%
labels= kmeans.reshape(in_data.shape[1], 
                       in_data.shape[2])

# %% [markdown]
# Let's take a look at the results, shall we?

# %%
plt.figure(figsize=(20,20))
plt.imshow(np.stack(labels).T)

# %% [markdown]
# Once again, writing this output array to a GeoTIFF file

# %%
tif_driver = gdal.GetDriverByName("GTiff")
in_gt = in_ds.GetGeoTransform()
in_prj = in_ds.GetProjection()
in_srs = osr.SpatialReference(wkt=in_prj)

out_tif = tif_driver.Create(out_tif, 
                            arr_list[0].shape[1],
                            arr_list[0].shape[0],
                            1,
                            gdal.GDT_Float64)

out_tif.SetProjection(in_srs.ExportToWkt())
out_tif.SetGeoTransform(in_gt)
out_band = out_tif.GetRasterBand(1)
out_band.WriteArray(labels.T)
out_tif.FlushCache()
